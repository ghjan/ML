# %%
longley
# Out:
#      GNP.deflator GNP     Unemployed Armed.Forces Population Year Employed
# 1947  83.0        234.289 235.6      159.0        107.608    1947 60.323
# 1948  88.5        259.426 232.5      145.6        108.632    1948 61.122
# 1949  88.2        258.054 368.2      161.6        109.773    1949 60.171
# 1950  89.5        284.599 335.1      165.0        110.929    1950 61.187
# 1951  96.2        328.975 209.9      309.9        112.075    1951 63.221
# 1952  98.1        346.999 193.2      359.4        113.270    1952 63.639
# 1953  99.0        365.385 187.0      354.7        115.094    1953 64.989
# 1954 100.0        363.112 357.8      335.0        116.219    1954 63.761
# 1955 101.2        397.469 290.4      304.8        117.388    1955 66.019
# 1956 104.6        419.180 282.2      285.7        118.734    1956 67.857
# 1957 108.4        442.769 293.6      279.8        120.445    1957 68.169
# 1958 110.8        444.546 468.1      263.7        121.950    1958 66.513
# ...

# %%
w = as.matrix(longley)

# %%
#install.packages('lars')
library(lars)
# Out:
# Loaded lars 1.2

# %%
laa = lars(w[,2:7],w[,1])
laa
# Out:
# Call:
# lars(x = w[, 2:7], y = w[, 1])
# R-squared: 0.993
# Sequence of LASSO moves:
#      GNP Year Armed.Forces Unemployed Employed Population Year Employed
# Var    1    5            3          2        6          4   -5       -6
# Step   1    2            3          4        5          6    7        8
#      Employed Year Employed Employed
# Var         6    5       -6        6
# Step        9   10       11       12

# %%
plot(laa)
# Out:
# Plot with title “LASSO”

# %%
summary(laa)
# Cp用来衡量多重共线性的严重程度，越小越好
# step8的时候，Cp最小 因此取到第8步 1 3 2 4几个自变量
# Out:
#    Df Rss        Cp
# 0  1  1746.86438 1210.056101
# 1  2  1439.50880  996.687080
# 2  3    32.30974   12.639960
# 3  4    23.17988    8.242517
# 4  5    22.90592   10.050547
# 5  6    22.63326   11.859492
# 6  7    18.03997   10.640901
# 7  6    14.73661    6.326179
# 8  5    13.53592    3.484840
# 9  6    13.26844    5.297411
# 10 7    13.01371    7.118919
# 11 6    12.93307    5.062414
# 12 7    12.84400    7.000000
